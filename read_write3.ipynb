# %%
import csv

# %%
#open file using with.
with open('data.csv') as f:
    #read file using dictreader
    myreader=csv.DictReader(f)
    #grab headers by reading a single line with next()
    headers=next(myreader)
    #iterate through the rest of the rows 
    for row in myreader:
        print(row['name'])
# Out:
# Manuel Thomas
# Chelsea Washington
# William Morrow
# Steven Gray
# Jill Pierce
# Alyssa Martinez
# Daniel Hoover
# Robert Moore
# Marissa Estrada
# Keith Hamilton
# John Morse
# Ryan Hill
# Chelsey Turner
# Eric Hamilton
# Veronica Wilkins
# Jennifer Patel
# Marc Skinner
# Sarah Rodriguez
# Erin Turner
# Ryan Miller
# Stephanie Michael MD
# Nicole Yoder
# Cheryl Ramirez
# Rachel Smith
# Robert Garcia
# Thomas Warren
# Christina Thompson
# Daniel Russell
# Rebecca Lopez
# Peter Hodges
# Dillon Farley
# Jason Jackson
# Frances Castillo
# Justin Hunter
# Kayla Brown
# Krista Miller
# Glenn Hernandez
# Jacqueline Watson
# Melissa Smith
# John Christensen
# Mark Holland
# Lori Hernandez
# Joseph Cooper
# Jacqueline Diaz
# Andrea Bishop
# Mike Wells
# Beverly Copeland
# Steven Robertson
# Jacob Turner
# Kevin Lambert
# April Fowler
# Alexander Mullins
# Caitlin Middleton
# Mr. Keith Glenn
# Lisa Sanchez
# David Reed
# Leah Higgins
# Cristina Valdez
# Michael Bridges
# Hunter Richards
# ...
